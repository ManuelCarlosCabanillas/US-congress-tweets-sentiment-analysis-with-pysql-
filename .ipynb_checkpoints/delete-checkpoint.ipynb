# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import datetime
from ast import literal_eval

from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

import math
import glob
from time import sleep

import modin.pandas as mpd
from modin.config import Engine

#Engine.put("dask")  # Modin will use Dask

# %%
import tweepy

consumer_key = "2rPzW7vP51aAh5TRmmZRG24v3"
consumer_secret = "Wwrsu8hpnpjWjS2IEUmTaOSXmZBbwdfu7S1E6qysn8mEhPqi3y"
access_token = "1274663812503830534-ydUKjD8cGElKLaXJnFcLlAyg5uRgIA"
access_token_secret = "u3egCwmLUz1IQ3rTD8D3t5B8bmzkWB6ontFIkpZHIzZDW"

# authorization of consumer key and consumer secret
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# set access to user's access key and access secret 
auth.set_access_token(access_token, access_token_secret)
  
# calling the api 
api = tweepy.API(auth)

# %% [markdown]
# **I opened the json file with a spark session for speed purposes, then I transfer it to Pandas as it is more confortable to work with.**
#
# **I will specifically work with Dask for improving load times through the modin library**

# %%
#import sparknlp
#from sparknlp.pretrained import PretrainedPipeline
#from pyspark.sql.functions import from_unixtime, to_date, year, udf, explode, split, col, length, rank, dense_rank, avg, sum
#from pyspark.sql.window import Window
#from pyspark.ml.linalg import Vectors
#from pyspark.ml.feature import VectorAssembler, StandardScaler
#from pyspark.ml.stat import Correlation
#from pyspark.ml.clustering import BisectingKMeans
#from pyspark.ml.evaluation import ClusteringEvaluator
#from pyspark.ml import Pipeline
#from pyspark.ml.tuning import CrossValidator, ParamGridBuilder


import nltk
from nltk.corpus import stopwords
from collections import Counter
from wordcloud import WordCloud

from textblob import TextBlob

# %%
#from pyspark.sql import SparkSession
#spark = SparkSession.builder \
#    .master("local[4]")\
#    .config("spark.driver.memory","4G")\
#    .config("spark.driver.maxResultSize", "2G") \
#    .config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.11:2.4.5")\
#    .config("spark.kryoserializer.buffer.max", "1G")\
#    .getOrCreate()

# %%
## Tweets
#tweets = spark.read.json('tweets.json').repartition(12).persist()
## Users
#users = spark.read.json('users.json').repartition(12).persist()
#
#spark.sql('SET spark.sql.shuffle.partitions=12')

# %%
#start = time.time()
#
#df_tweets= tweets.toPandas() # Transfered it to a Pandas Dataframe
#
#end = time.time()
#
#print ("Time elapsed:", end - start)
#

# %%
#df_users = users.toPandas() # Transfered it to a Pandas Dataframe

# %%
#df_tweets.to_csv('tweets.csv')

# %%
#df_users.to_csv('users.csv')

# %% [markdown]
# **Below a comparison of load time with normal pandas and with modin pandas which has Dask intefgrated**

# %%
start = time.time()

tweets_df = pd.read_csv('tweets.csv') # Transfered it to a Pandas Dataframe
users_df = pd.read_csv('users.csv')

end = time.time()

print ("Time elapsed:", end - start)
# Out:
# DtypeWarning: Columns (30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
# Time elapsed: 10.583638668060303

# %%
start = time.time()

tweets_df = pd.read_csv('tweets.csv')
users_df = pd.read_csv('users.csv')

end = time.time()

print ("Time elapsed:", end - start)
# Out:
# Time elapsed: 11.1493079662323

# %% [markdown]
# **General overview of the data**

# %%
tweets_df.info() # General view of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243370 entries, 0 to 1243369
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Unnamed: 0                 1243370 non-null  int64
#  1   contributors               0 non-null        float64
#  2   coordinates                2734 non-null     object
#  3   created_at                 1243370 non-null  int64
#  4   display_text_range         1243370 non-null  object
#  5   entities                   1243370 non-null  object
#  6   extended_entities          298040 non-null   object
#  7   favorite_count             1243370 non-null  int64
#  8   favorited                  1243370 non-null  bool
#  9   geo                        2734 non-null     object
#  10  id                         1243370 non-null  int64
#  11  id_str                     1243370 non-null  int64
#  12  in_reply_to_screen_name    65411 non-null    object
#  13  in_reply_to_status_id      54146 non-null    float64
#  14  in_reply_to_status_id_str  54146 non-null    float64
#  15  in_reply_to_user_id        65411 non-null    float64
#  16  in_reply_to_user_id_str    65411 non-null    float64
#  17  is_quote_status            1243370 non-null  bool
#  18  lang                       1243370 non-null  object
#  19  place                      22450 non-null    object
#  20  possibly_sensitive         770180 non-null   object
#  21  quoted_status_id           56418 non-null    float64
#  22  quoted_status_id_str       56418 non-null    float64
#  23  retweet_count              1243370 non-null  int64
#  24  retweeted                  1243370 non-null  bool
#  25  screen_name                1243370 non-null  object
#  26  source                     1243317 non-null  object
#  27  text                       1243370 non-null  object
#  28  truncated                  1243370 non-null  bool
#  29  user_id                    1243370 non-null  int64
#  30  withheld_copyright         1 non-null        object
#  31  withheld_in_countries      1 non-null        object
#  32  withheld_scope             1 non-null        object
# dtypes: bool(4), float64(7), int64(7), object(15)
# memory usage: 279.8+ MB

# %%
users_df.info() # General view of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 43 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          548 non-null    int64
#  1   contributors_enabled                548 non-null    bool
#  2   created_at                          548 non-null    object
#  3   default_profile                     548 non-null    bool
#  4   default_profile_image               548 non-null    bool
#  5   description                         539 non-null    object
#  6   entities                            545 non-null    object
#  7   favourites_count                    548 non-null    int64
#  8   follow_request_sent                 548 non-null    bool
#  9   followers_count                     548 non-null    int64
#  10  following                           548 non-null    bool
#  11  friends_count                       548 non-null    int64
#  12  geo_enabled                         548 non-null    bool
#  13  has_extended_profile                548 non-null    bool
#  14  id                                  548 non-null    int64
#  15  id_str                              548 non-null    int64
#  16  is_translation_enabled              548 non-null    bool
#  17  is_translator                       548 non-null    bool
#  18  lang                                548 non-null    object
#  19  listed_count                        548 non-null    int64
#  20  location                            414 non-null    object
#  21  name                                548 non-null    object
#  22  notifications                       548 non-null    bool
#  23  profile_background_color            548 non-null    object
#  24  profile_background_image_url        512 non-null    object
#  25  profile_background_image_url_https  512 non-null    object
#  26  profile_background_tile             548 non-null    bool
#  27  profile_banner_url                  513 non-null    object
#  28  profile_image_url                   548 non-null    object
#  29  profile_image_url_https             548 non-null    object
#  30  profile_link_color                  548 non-null    object
#  31  profile_sidebar_border_color        548 non-null    object
#  32  profile_sidebar_fill_color          548 non-null    object
#  33  profile_text_color                  548 non-null    object
#  34  profile_use_background_image        548 non-null    bool
#  35  protected                           548 non-null    bool
#  36  screen_name                         548 non-null    object
#  37  statuses_count                      548 non-null    int64
#  38  time_zone                           503 non-null    object
#  39  translator_type                     548 non-null    object
#  40  url                                 513 non-null    object
#  41  utc_offset                          503 non-null    float64
#  42  verified                            548 non-null    bool
# dtypes: bool(14), float64(1), int64(8), object(20)
# memory usage: 131.8+ KB

# %%
users_df.head()
# Out:
#    Unnamed: 0  contributors_enabled  created_at  default_profile  \
# 0           0                 False  1302113133            False
# 1           1                 False  1236024242            False
# 2           2                 False  1274900032            False
# 3           3                 False  1418247892             True
# 4           4                 False  1420495744            False
#
#    default_profile_image                                        description  \
# 0                  False  I am honored to serve the people of Tennessee'...
# 1                  False  Member of Congress, Chairman of @transport, an...
# 2                  False  Proudly representing Pennsylvania's 1st Distri...
# 3                  False  Husband, father, hockey fan, and Congressman f...
# 4                  False  Representing Virginia's 8th District in Congre...
#
#                                             entities  favourites_count  \
# 0  Row(description=Row(urls=[]), url=Row(urls=[Ro...               179
# 1  Row(description=Row(urls=[]), url=Row(urls=[Ro...                 7
# 2  Row(description=Row(urls=[]), url=Row(urls=[Ro...                40
# 3  Row(description=Row(urls=[]), url=Row(urls=[Ro...               222
# 4  Row(description=Row(urls=[]), url=Row(urls=[Ro...             12507
#
#    follow_request_sent  followers_count  ...  profile_text_color  \
# 0                False            31906  ...              333333
# 1                False            17424  ...              666666
# 2                False            11044  ...              333333
# 3                False             5557  ...              333333
# 4                False            31002  ...              333333
#
#    profile_use_background_image  protected      screen_name  statuses_count  \
# 0                          True      False  MarshaBlackburn            5338
# 1                          True      False   RepBillShuster            3142
# 2                          True      False         RepBrady             675
# 3                          True      False      RepTomEmmer            2628
# 4                          True      False      RepDonBeyer            7289
#
#                     time_zone  translator_type                      url  \
# 0      Atlantic Time (Canada)             none   http://t.co/uIRgQmKWY5
# 1  Eastern Time (US & Canada)             none   http://t.co/cXqRPxrbJ1
# 2  Eastern Time (US & Canada)             none   http://t.co/UXBZB1hRh5
# 3  Pacific Time (US & Canada)             none   http://t.co/jU8TYBqqHL
# 4  Eastern Time (US & Canada)             none  https://t.co/GLUWQ3oyIM
#
#   utc_offset  verified
# 0   -10800.0      True
# 1   -14400.0      True
# 2   -14400.0     False
# 3   -25200.0      True
# 4   -14400.0      True
#
# [5 rows x 43 columns]

# %%
pd.set_option('max_columns', None)
pd.set_option('display.max_colwidth', -1)
tweets_df.head()
# Out:
# FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#    Unnamed: 0  contributors coordinates  created_at display_text_range  \
# 0  0          NaN            NaN         1326308786  [0, 138]
# 1  1          NaN            NaN         1310063586  [0, 105]
# 2  2          NaN            NaN         1315430399  [0, 118]
# 3  3          NaN            NaN         1363974613  [0, 115]
# 4  4          NaN            NaN         1360103452  [0, 112]
#
#                                                                                                                                                                                                                                                                                                                           entities  \
# 0  Row(hashtags=[Row(indices=[101, 110], text='mentorDE'), Row(indices=[132, 138], text='netde')], media=None, symbols=[], urls=[Row(display_url='bit.ly/wd6w0q', expanded_url='http://bit.ly/wd6w0q', indices=[111, 131], url='http://t.co/9FGc3Oqh')], user_mentions=[])
# 1  Row(hashtags=[], media=None, symbols=[], urls=[], user_mentions=[])
# 2  Row(hashtags=[Row(indices=[94, 103], text='sctweets'), Row(indices=[104, 111], text='scnews'), Row(indices=[112, 118], text='4jobs')], media=None, symbols=[], urls=[], user_mentions=[])
# 3  Row(hashtags=[Row(indices=[0, 11], text='California'), Row(indices=[82, 92], text='ACAturns3')], media=None, symbols=[], urls=[Row(display_url='healthcare.gov/law/informatio…', expanded_url='http://www.healthcare.gov/law/information-for-you/ca.html', indices=[93, 115], url='http://t.co/RnRhi8QUBF')], user_mentions=[])
# 4  Row(hashtags=[Row(indices=[5, 10], text='STEM')], media=None, symbols=[], urls=[Row(display_url='ht.ly/hrXb0', expanded_url='http://ht.ly/hrXb0', indices=[31, 51], url='http://t.co/FWiReooi')], user_mentions=[Row(id=972651, id_str='972651', indices=[21, 30], name='Mashable', screen_name='mashable')])
#
#   extended_entities  favorite_count  favorited  geo                  id  \
# 0  NaN               0               False      NaN  157176556937166848
# 1  NaN               0               False      NaN  89039252083576832
# 2  NaN               0               False      NaN  111549295026647040
# 3  NaN               0               False      NaN  315158486059200513
# 4  NaN               3               False      NaN  298921660260687872
#
#                id_str in_reply_to_screen_name  in_reply_to_status_id  \
# 0  157176556937166848  NaN                    NaN
# 1  89039252083576832   NaN                    NaN
# 2  111549295026647040  NaN                    NaN
# 3  315158486059200513  NaN                    NaN
# 4  298921660260687872  NaN                    NaN
#
#    in_reply_to_status_id_str  in_reply_to_user_id  in_reply_to_user_id_str  \
# 0 NaN                        NaN                  NaN
# 1 NaN                        NaN                  NaN
# 2 NaN                        NaN                  NaN
# 3 NaN                        NaN                  NaN
# 4 NaN                        NaN                  NaN
#
#    is_quote_status lang place possibly_sensitive  quoted_status_id  \
# 0  False            en   NaN   False             NaN
# 1  False            en   NaN   NaN               NaN
# 2  False            en   NaN   NaN               NaN
# 3  False            en   NaN   False             NaN
# 4  False            en   NaN   False             NaN
#
#    quoted_status_id_str  retweet_count  retweeted    screen_name  \
# 0 NaN                    5              False      JohnCarneyDE
# 1 NaN                    0              False      Call_Me_Dutch
# 2 NaN                    0              False      TGowdySC
# 3 NaN                    3              False      RepLowenthal
# 4 NaN                    3              False      JeffFlake
#
#                                                                                 source  \
# 0  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 1  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 3  <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>
# 4  <a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>
#
#                                                                                                                                          text  \
# 0  Jan is Nat'l Mentoring Month. Take a step towards positively shaping a child's future thru mentoring #mentorDE http://t.co/9FGc3Oqh #netde
# 1  Debating the FY 2012 Defense Appropriations bill. Happy to see lots of votes on policy and spending cuts.
# 2  Just completed the 1st day of the SC/DC Chamber Fly-in.  Had a great group of speakers today! #sctweets #scnews #4jobs
# 3  #California residents with private insurance benefit from $73,905,280 in rebates. #ACAturns3 http://t.co/RnRhi8QUBF
# 4  Cool #STEM jobs from @Mashable http://t.co/FWiReooi We need more foreign-born STEM graduates to stay in the U.S.
#
#    truncated     user_id withheld_copyright withheld_in_countries  \
# 0  False      237770636   NaN                NaN
# 1  False      305620929   NaN                NaN
# 2  False      237348797   NaN                NaN
# 3  False      1055730738  NaN                NaN
# 4  False      16056306    NaN                NaN
#
#   withheld_scope
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
#fixup some columns 

tweets_df['in_reply_to_status_id'] = tweets_df['in_reply_to_status_id'].astype(pd.Int64Dtype())
tweets_df['in_reply_to_status_id_str'] = tweets_df['in_reply_to_status_id_str'].astype(pd.Int64Dtype())
tweets_df['in_reply_to_user_id'] = tweets_df['in_reply_to_user_id'].astype(pd.Int64Dtype())
tweets_df['in_reply_to_user_id_str'] = tweets_df['in_reply_to_user_id_str'].astype(pd.Int64Dtype())
tweets_df['quoted_status_id'] = tweets_df['quoted_status_id'].astype(pd.Int64Dtype())
tweets_df['quoted_status_id_str'] = tweets_df['quoted_status_id_str'].astype(pd.Int64Dtype())

tweets_df['display_text_range'] = tweets_df.display_text_range.apply(literal_eval) # pass string to list format

tweets_df=tweets_df.drop('contributors', 1) # as it only have Nans
tweets_df=tweets_df.drop('coordinates', 1) # not usefull for analysis purpose

# Prep created_at column
tweets_df['created_at']=  tweets_df['created_at'].apply(datetime.datetime.fromtimestamp)
# Out:
# FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
# create new columns with text start position and text end position
tweets_df[['text_start','text_stop']] = pd.DataFrame(tweets_df.display_text_range.values.tolist(), index= tweets_df.index)

# %%
tweets_df[['display_text_range','text_start','text_stop']].head()
# Out:
#   display_text_range  text_start  text_stop
# 0  [0, 138]           0           138
# 1  [0, 105]           0           105
# 2  [0, 118]           0           118
# 3  [0, 115]           0           115
# 4  [0, 112]           0           112

# %%
ids = tweets_df.loc[tweets_df.is_quote_status].quoted_status_id.to_list()

# %%
ids = [x for x in ids if str(x) != '<NA>']

# %%
ids
# Out:
# [502533885184708608,
#  621863187839717376,
#  613420513080279040,
#  618220389395619840,
#  622095529212805120,
#  589148642868645888,
#  618978745089593344,
#  588030283380822016,
#  625746001916239872,
#  598200928022429696,
#  618796581928738816,
#  607937054752698368,
#  606570769200627712,
#  626037174547447808,
#  619590845973422080,
#  621522746200223744,
#  591226070327779328,
#  610825145347915776,
#  605717929590706176,
#  587569119651848192,
#  621745647352455168,
#  626739637193732096,
#  620933012998488064,
#  615537147613978624,
#  598899781684043776,
#  619167666708828160,
#  613392504189243392,
#  618898843036311552,
#  591680539196858368,
#  605914404308189184,
#  623979992414855168,
#  616705453150474240,
#  622092113623281664,
#  613793743465005056,
#  622172450571186176,
#  613340761644380160,
#  593488654061932544,
#  611592877710409728,
#  605759626861146112,
#  604309675241291776,
#  604357870382141440,
#  593430791713067008,
#  600723585372663808,
#  613737309914165248,
#  625331692631240704,
#  609518642187882496,
#  613767037563834368,
#  626003203767799808,
#  586569386661699584,
#  610458002714402816,
#  626037174547447808,
#  614455340344586240,
#  613738467529523200,
#  611909414551883776,
#  627164270200008704,
#  626015749828702208,
#  606914764120465408,
#  613734830224842752,
#  595360091466895360,
#  619869362279874560,
#  596673913372872704,
#  590546084545585152,
#  628289648687714304,
#  622068357387419648,
#  596699685701681152,
#  612941418676506624,
#  588421695263940608,
#  626751518826471424,
#  598150132480245760,
#  616224762365227008,
#  627856799937380352,
#  609047453707292672,
#  623178790643048448,
#  624289216839561216,
#  593143728556105728,
#  616754688973766656,
#  615923097154269184,
#  619158990224756736,
#  628306456777990144,
#  621311418898493440,
#  626688204175884288,
#  626002903615074304,
#  619524665539559424,
#  613472663026143232,
#  688853910417571840,
#  712441461581676544,
#  705757878179799040,
#  702779331559473152,
#  700716035100569600,
#  701873255506956288,
#  709896072223531008,
#  693507986954809344,
#  ...]

# %%
all_data = []
start = 0
end = 100
limit = len(ids)
i = math.ceil(limit / 100)

# %%
for go in range(i):
    print('currently getting {} - {}'.format(start, end))
    sleep(6) # needed to prevent hitting API rate limit
    id_batch = ids[start:end]
    start += 100
    end +=100
    tweets = api.lookup_statuses(id_batch, tweet_mode="extended")
    for tweet in tweets:
        all_data.append(dict(tweet._json))
# Out:
# currently getting 0 - 100
# currently getting 100 - 200
# currently getting 200 - 300
# currently getting 300 - 400
# currently getting 400 - 500
# currently getting 500 - 600
# currently getting 600 - 700
# currently getting 700 - 800
# currently getting 800 - 900
# currently getting 900 - 1000
# currently getting 1000 - 1100
# currently getting 1100 - 1200
# currently getting 1200 - 1300
# currently getting 1300 - 1400
# currently getting 1400 - 1500
# currently getting 1500 - 1600
# currently getting 1600 - 1700
# currently getting 1700 - 1800
# currently getting 1800 - 1900
# currently getting 1900 - 2000
# currently getting 2000 - 2100
# currently getting 2100 - 2200
# currently getting 2200 - 2300
# currently getting 2300 - 2400
# currently getting 2400 - 2500
# currently getting 2500 - 2600
# currently getting 2600 - 2700
# currently getting 2700 - 2800
# currently getting 2800 - 2900
# currently getting 2900 - 3000
# currently getting 3000 - 3100
# currently getting 3100 - 3200
# currently getting 3200 - 3300
# currently getting 3300 - 3400
# currently getting 3400 - 3500
# currently getting 3500 - 3600
# currently getting 3600 - 3700
# currently getting 3700 - 3800
# currently getting 3800 - 3900
# currently getting 3900 - 4000
# currently getting 4000 - 4100
# currently getting 4100 - 4200
# currently getting 4200 - 4300
# currently getting 4300 - 4400
# currently getting 4400 - 4500
# currently getting 4500 - 4600
# currently getting 4600 - 4700
# currently getting 4700 - 4800

# %%
# Setup additional tables (quoted tweets / quoted tweets users)

quoted_tweets = pd.DataFrame(all_data)
quoted_tweets = quoted_tweets.rename(columns={'id' : 'tweet_id'}) # rename id to tweet id
quoted_tweets_users=quoted_tweets.user.apply(pd.Series).set_index(quoted_tweets.tweet_id)

# Drop dict fields - pandasql dont like them
quoted_tweets = quoted_tweets.drop(['entities','extended_entities','user'], axis = 1)
quoted_tweets_users = quoted_tweets_users.iloc[:,0:11].drop(['entities'], axis =1)

# added to keep consistency with other data being extracted
quoted_tweets_users.screen_name = "@" + quoted_tweets_users.screen_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14004/2485266401.py in <module>
#       3 quoted_tweets = pd.DataFrame(all_data)
#       4 quoted_tweets = quoted_tweets.rename(columns={'id' : 'tweet_id'}) # rename id to tweet id
# ----> 5 quoted_tweets_users=quoted_tweets.user.apply(pd.Series).set_index(quoted_tweets.tweet_id)
#       6
#       7 # Drop dict fields - pandasql dont like them
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'user'

# %% [markdown]
# ## Pandas Display options

# %%
pd.set_option('display.max_colwidth',-1)
pd.set_option('display.max_rows',100)
# Out:
# FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %% [markdown]
# ## tweets_subdf

# %%
tweets_subdf = tweets_df[['id','created_at','favorite_count','favorited','retweet_count','text','text_start',"text_stop"]]

# %%
print('start_date: ', tweets_subdf.created_at.min())
print('start_date: ', tweets_subdf.created_at.max())
# Out:
# start_date:  2008-08-04 19:28:51
# start_date:  2017-06-06 19:16:00

# %%
tweets_subdf.dtypes
# Out:
# id                int64
# created_at        datetime64[ns]
# favorite_count    int64
# favorited         bool
# retweet_count     int64
# text              object
# text_start        int64
# text_stop         int64
# dtype: object

# %%
# extract just the text into a separate column
just_the_text = []
for idx in tweets_subdf.index:
    tweet =tweets_subdf.loc[idx]['text']
    start =tweets_subdf.loc[idx]['text_start']
    stop  =tweets_subdf.loc[idx]['text_stop']
    just_the_text.append(tweet[start:stop])

tweets_subdf['just_text'] = just_the_text
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tweets_subdf.loc[tweets_subdf.text!=tweets_subdf.just_text]
# Out:
#                          id          created_at  favorite_count  favorited  \
# 62694    723554497927217152 2016-04-22 18:50:09  3               False
# 62696    722521323772227587 2016-04-19 22:24:42  9               False
# 62699    730763593998860288 2016-05-12 16:16:32  16              False
# 62705    745773371745394689 2016-06-23 02:20:02  143             False
# 62715    732958018602733570 2016-05-18 17:36:23  6               False
# ...                     ...                 ... ..                 ...
# 1243357  871805063202836480 2017-06-05 21:04:59  305             False
# 1243358  870987255795593216 2017-06-03 14:55:18  2               False
# 1243361  870404291231657990 2017-06-02 00:18:49  45              False
# 1243364  871741094802927616 2017-06-05 16:50:47  3               False
# 1243369  869618956008554500 2017-05-30 20:18:10  21              False
#
#          retweet_count  \
# 62694    1
# 62696    2
# 62699    2
# 62705    59
# 62715    3
# ...     ..
# 1243357  102
# 1243358  1
# 1243361  4
# 1243364  1
# 1243369  7
#
#                                                                                                                                                                                 text  \
# 62694    From stocking shelves to helping bag ice for customers, the QuikTrip team is all smiles. #MMB #TX33 https://t.co/WG3YsQXVIk
# 62696    Met w/folks from MHA Nation &amp; Standing Rock about priorities in their tribal communities. https://t.co/nFB3mPm3PC
# 62699    Welcoming the leaders of Denmark, Finland, Iceland, Norway and Sweden - and my family - to  DC.  #NordicUSAsummit https://t.co/eqvdDPFOCL
# 62705    Dems are united for change. Our communities deserve a vote. #NoBillNoBreak #HoldTheFloor https://t.co/VrypLH7fQZ
# 62715    I'm chatting with students at Mulberry-Pleasant View about how a bill becomes a law and my work in Congress. #ar4 https://t.co/KqQmt7OeTv
# ...                                                                                                                                            ...
# 1243357  With Washington taking a wrecking ball to our health care system, ensuring protections for New Yorkers is more important than ever. https://t.co/yKZ8TSdNzR
# 1243358  First stop in Trumansburg. Thanks to those who came out https://t.co/DsQXPhcSsQ
# 1243361  https://t.co/bkd3EVdx3u
# 1243364  American ingenuity &amp; innovation beat government rules &amp; regulations every time. More from yesterday's email update: https://t.co/5sLSftrVyi https://t.co/8ezPmi3Gyl
# 1243369  Absolutely. Big win for the Seagulls on Sunday - congrats @SalisburyU! What an incredibly talented team. https://t.co/VvI4lK0dSn
#
#          text_start  text_stop  \
# 62694    0           99
# 62696    0           93
# 62699    0           113
# 62705    0           88
# 62715    0           113
# ...     ..           ...
# 1243357  0           131
# 1243358  0           55
# 1243361  0           0
# 1243364  0           147
# 1243369  0           104
#
#                                                                                                                                                    just_text
# 62694    From stocking shelves to helping bag ice for customers, the QuikTrip team is all smiles. #MMB #TX33
# 62696    Met w/folks from MHA Nation &amp; Standing Rock about priorities in their tribal communities.
# 62699    Welcoming the leaders of Denmark, Finland, Iceland, Norway and Sweden - and my family - to  DC.  #NordicUSAsummit
# 62705    Dems are united for change. Our communities deserve a vote. #NoBillNoBreak #HoldTheFloor
# 62715    I'm chatting with students at Mulberry-Pleasant View about how a bill becomes a law and my work in Congress. #ar4
# ...                                                                                                                    ...
# 1243357  With Washington taking a wrecking ball to our health care system, ensuring protections for New Yorkers is more important than ever.
# 1243358  First stop in Trumansburg. Thanks to those who came out
# 1243361
# 1243364  American ingenuity &amp; innovation beat government rules &amp; regulations every time. More from yesterday's email update: https://t.co/5sLSftrVyi
# 1243369  Absolutely. Big win for the Seagulls on Sunday - congrats @SalisburyU! What an incredibly talented team.
#
# [168037 rows x 9 columns]

# %%
tweets_subdf.head()
# Out:
#                    id          created_at  favorite_count  favorited  \
# 0  157176556937166848 2012-01-11 20:06:26  0               False
# 1  89039252083576832  2011-07-07 20:33:06  0               False
# 2  111549295026647040 2011-09-07 23:19:59  0               False
# 3  315158486059200513 2013-03-22 18:50:13  0               False
# 4  298921660260687872 2013-02-05 23:30:52  3               False
#
#    retweet_count  \
# 0  5
# 1  0
# 2  0
# 3  3
# 4  3
#
#                                                                                                                                          text  \
# 0  Jan is Nat'l Mentoring Month. Take a step towards positively shaping a child's future thru mentoring #mentorDE http://t.co/9FGc3Oqh #netde
# 1  Debating the FY 2012 Defense Appropriations bill. Happy to see lots of votes on policy and spending cuts.
# 2  Just completed the 1st day of the SC/DC Chamber Fly-in.  Had a great group of speakers today! #sctweets #scnews #4jobs
# 3  #California residents with private insurance benefit from $73,905,280 in rebates. #ACAturns3 http://t.co/RnRhi8QUBF
# 4  Cool #STEM jobs from @Mashable http://t.co/FWiReooi We need more foreign-born STEM graduates to stay in the U.S.
#
#    text_start  text_stop  \
# 0  0           138
# 1  0           105
# 2  0           118
# 3  0           115
# 4  0           112
#
#                                                                                                                                     just_text
# 0  Jan is Nat'l Mentoring Month. Take a step towards positively shaping a child's future thru mentoring #mentorDE http://t.co/9FGc3Oqh #netde
# 1  Debating the FY 2012 Defense Appropriations bill. Happy to see lots of votes on policy and spending cuts.
# 2  Just completed the 1st day of the SC/DC Chamber Fly-in.  Had a great group of speakers today! #sctweets #scnews #4jobs
# 3  #California residents with private insurance benefit from $73,905,280 in rebates. #ACAturns3 http://t.co/RnRhi8QUBF
# 4  Cool #STEM jobs from @Mashable http://t.co/FWiReooi We need more foreign-born STEM graduates to stay in the U.S.

# %% [markdown]
# Additional tables to look at some stats

# %%
tweet_freq_hour = pysqldf("SELECT strftime('%H', created_at) as hour, count(*) as cnt FROM tweets_subdf group by hour;")
tweet_freq_month = pysqldf("SELECT strftime('%m', created_at) as month, count(*) as cnt FROM tweets_subdf group by month;")
tweet_freq_year = pysqldf("SELECT strftime('%Y', created_at) as year, count(*) as cnt FROM tweets_subdf group by year;")

# %%
tweet_freq_year
# Out:
#    year     cnt
# 0  2008  112
# 1  2009  8234
# 2  2010  13761
# 3  2011  35165
# 4  2012  50789
# 5  2013  124432
# 6  2014  168311
# 7  2015  258254
# 8  2016  354920
# 9  2017  229392

# %% [markdown]
# ## Tweets user table

# %%
# Table that holds info about each user and the tweet they were part of (e.g public, mention, retweet)

# %%
tweets_subdf
# Out:
#                          id          created_at  favorite_count  favorited  \
# 0        157176556937166848 2012-01-11 20:06:26  0               False
# 1        89039252083576832  2011-07-07 20:33:06  0               False
# 2        111549295026647040 2011-09-07 23:19:59  0               False
# 3        315158486059200513 2013-03-22 18:50:13  0               False
# 4        298921660260687872 2013-02-05 23:30:52  3               False
# ...                     ...                 ... ..                 ...
# 1243365  868114711719661568 2017-05-26 16:40:50  224             False
# 1243366  870301345726771200 2017-06-01 17:29:44  5               False
# 1243367  867137080660512768 2017-05-23 23:56:05  0               False
# 1243368  867423681940729856 2017-05-24 18:54:56  0               False
# 1243369  869618956008554500 2017-05-30 20:18:10  21              False
#
#          retweet_count  \
# 0        5
# 1        0
# 2        0
# 3        3
# 4        3
# ...     ..
# 1243365  56
# 1243366  0
# 1243367  1
# 1243368  4308
# 1243369  7
#
#                                                                                                                                                      text  \
# 0        Jan is Nat'l Mentoring Month. Take a step towards positively shaping a child's future thru mentoring #mentorDE http://t.co/9FGc3Oqh #netde
# 1        Debating the FY 2012 Defense Appropriations bill. Happy to see lots of votes on policy and spending cuts.
# 2        Just completed the 1st day of the SC/DC Chamber Fly-in.  Had a great group of speakers today! #sctweets #scnews #4jobs
# 3        #California residents with private insurance benefit from $73,905,280 in rebates. #ACAturns3 http://t.co/RnRhi8QUBF
# 4        Cool #STEM jobs from @Mashable http://t.co/FWiReooi We need more foreign-born STEM graduates to stay in the U.S.
# ...                                                                                                                   ...
# 1243365  Getting ready to join @RepTedDeutch &amp; @RepDWStweets to keep up the fight to pass the Equality Act. #EqualityForward
# 1243366  Good news for @SullivanCntyGov and #ValleyFalls https://t.co/X8fcMuIHjO
# 1243367  RT @HouseSBCDems: .@NydiaVelazquez recently introduced new bills to foster #entrepreneurship &amp; economic recovery in #PuertoRico. More: http…
# 1243368  RT @McFaul: It's unusual. https://t.co/CKOQMHjmKo
# 1243369  Absolutely. Big win for the Seagulls on Sunday - congrats @SalisburyU! What an incredibly talented team. https://t.co/VvI4lK0dSn
#
#          text_start  text_stop
# 0        0           138
# 1        0           105
# 2        0           118
# 3        0           115
# 4        0           112
# ...     ..           ...
# 1243365  0           119
# 1243366  0           71
# 1243367  0           144
# 1243368  0           49
# 1243369  0           104
#
# [1243370 rows x 8 columns]

# %%
public_tweets = []
for idx in tweets_subdf.index:
    tweet = tweets_subdf.loc[idx]['text']
    if (tweet[:2] == '.@'):
        # It's a public tweet on purpose
        parts = tweet.split(" ")
        public_tweets.append([parts[0][1:],"public",tweets_subdf.loc[idx]['id']])

who_he_mentions = [] 
for idx in tweets_subdf.index:
    tweet = tweets_subdf.loc[idx]['text']
    if (tweet[:1] == '.@'):
        # It's a reply/mention
        parts = tweet.split()
        for i in range (0, len(parts)):
            if (parts[i][0]=='@'):
                 who_he_mentions.append([parts[i],"mention",tweets_subdf.loc[idx]['id']])        

who_he_rts = pysqldf("select screen_name, 'retweet', tweet_id from quoted_tweets_users;").values.tolist()

combined = public_tweets + who_he_mentions + who_he_rts

tweet_user = pd.DataFrame(combined, columns=['username', 'tweet_type', 'tweet_id'])

# Example ... Tweets that had the highest number of users mentioned

display(pysqldf("""select tweet_id, tweet_type, count(*)
            from tweet_user
            group by tweet_id
            order by count(*) desc;""").head())

display(pysqldf("""select * from tweets_subdf where id = 157176556937166848"""))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\Bridge\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
# -> 1802                     self.dialect.do_execute(
#    1803                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\Bridge\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: no such table: quoted_tweets_users
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\Bridge\lib\site-packages\pandasql\sqldf.py in __call__(self, query, env)
#      60             try:
# ---> 61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     627     else:
# --> 628         return pandas_sql.read_query(
#     629             sql,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#
# ~\anaconda3\envs\Bridge\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1273
# -> 1274             return self._exec_driver_sql(
#    1275                 statement,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\sqlalchemy\engine\base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1577         dialect = self.dialect
# -> 1578         ret = self._execute_context(
#    1579             dialect,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
# -> 1845             self._handle_dbapi_exception(
#    1846                 e, statement, parameters, cursor, context
#
# ~\anaconda3\envs\Bridge\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
# -> 2026                 util.raise_(
#    2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#
# ~\anaconda3\envs\Bridge\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\envs\Bridge\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
# -> 1802                     self.dialect.do_execute(
#    1803                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\Bridge\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# OperationalError: (sqlite3.OperationalError) no such table: quoted_tweets_users
# [SQL: select screen_name, 'retweet', tweet_id from quoted_tweets_users;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14004/1452182788.py in <module>
#      17                  who_he_mentions.append([parts[i],"mention",tweets_subdf.loc[idx]['id']])
#      18
# ---> 19 who_he_rts = pysqldf("select screen_name, 'retweet', tweet_id from quoted_tweets_users;").values.tolist()
#      20
#      21 combined = public_tweets + who_he_mentions + who_he_rts
#
# ~\AppData\Local\Temp/ipykernel_14004/3792765166.py in <lambda>(q)
#       9
#      10 from pandasql import sqldf
# ---> 11 pysqldf = lambda q: sqldf(q, globals())
#      12
#      13 import math
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandasql\sqldf.py in sqldf(query, env, db_uri)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandasql\sqldf.py in __call__(self, query, env)
#      61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
# ---> 63                 raise PandaSQLException(ex)
#      64             except ResourceClosedError:
#      65                 # query returns nothing
#
# PandaSQLException: (sqlite3.OperationalError) no such table: quoted_tweets_users
# [SQL: select screen_name, 'retweet', tweet_id from quoted_tweets_users;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# get users with their public counts

public_totals = pysqldf("""select username, tweet_type, count(*) as public_cnt
            from tweet_user
            where tweet_type = 'public'
            group by 1,2;""")

public_totals_df = public_totals[['username', 'public_cnt']]

# %%
# get users with their mention counts
mention_totals = pysqldf("""select username, tweet_type, count(*) as mention_cnt
                    from tweet_user
                    where tweet_type = 'mention'
                    group by 1,2;""")

mention_totals_df = mention_totals[['username', 'mention_cnt']]

# Get users with their retweet counts

retweet_totals = pysqldf("""select username, tweet_type, count(*) as retweet_cnt
            from tweet_user
            where tweet_type = 'retweet'
            group by 1,2;""")

retweet_totals_df = retweet_totals[['username', 'retweet_cnt']]

data_frames = [public_totals_df, mention_totals_df,retweet_totals_df]
user = reduce(lambda left,right:pd.merge(left,right,on=['username'],
                                                how='outer'), data_frames)

print("PUBLIC")
display(pysqldf("select * from user where public_cnt is not null order by mention_cnt desc;").head(15))


print("MENTIONS")
display(pysqldf("select * from user where mention_cnt is not null order by mention_cnt desc;").head(10))

print("RETWEETS")
display(pysqldf("select * from user where retweet_cnt is not null order by retweet_cnt desc;").head(10))

print("MENTIONS AND RETWEETS")
display(pysqldf("""select username, mention_cnt, retweet_cnt
                from user
                where mention_cnt is not null
                and retweet_cnt is not null
                order by retweet_cnt desc""").head(10))

# %% [markdown]
# ## STATS

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
em_tweet.describe()

# %%
tweet_freq_year.describe()
# Out:
#             cnt
# count 10.00
# mean  124337.00
# std   124084.34
# min   112.00
# 25%   19112.00
# 50%   87610.50
# 75%   214121.75
# max   354920.00

# %%
tweet_freq_year.plot('year','cnt')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Now lets check column by column and drop non usefull ones for our analysis

# %%
tweets_df.created_at.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Some functions**

# %%
# Takes a sentence, splits it and count the wordsabs

def word_count(str):
    counts = dict()
    words = str.split()
    
    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
    
    return counts

# Takes an array of tweets and gives me counts
def tweet_counts(tweet_array, threshold=10):
    unique, counts = np.unique(np.array(tweet_array), return_counts=True)
    count_dict = dict(zip(unique, counts))
    
    return[(k,v) for k, v in count_dict.items() if v > threshold]

# %% [markdown]
# **Look for tweets that are replies or are to specific people**

# %%
import numpy as np

who_he_replies_to =[]
for tweet in tweets_df.text:
    if (tweet[:1]=='@'):
        # It´ss a reply
        parts = tweet.split()
        for i in range (0, len(parts)):
            if (parts[i][0]=='@'):
                who_he_replies_to.append(parts[i])

# %%
#tweet_counts(who_he_replies_to,5)

# %%
replies_df = pd.DataFrame(tweet_counts(who_he_replies_to,5), columns=['who','count']).sort_values('count', ascending = False)
replies_df
# Out:
#                    who  count
# 416   @POTUS            532
# 1069  @realDonaldTrump  323
# 0     @                 269
# 524   @RepLipinski      230
# 242   @HouseGOP         211
# ...         ...         ...
# 992   @lwherron         6
# 139   @EIAgov           6
# 300   @KMartinezReport  6
# 480   @RepCuellar       6
# 891   @digiphile        6
#
# [1183 rows x 2 columns]
